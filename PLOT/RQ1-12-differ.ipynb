# %% [markdown]
# # RQ1

# %% [markdown]
# ## RQ 1a

# %%
import matplotlib.pyplot as plt

# %%
index_overlap_signal = []
for i in s_w_overlap:
    index_overlap_signal.append(Signal_freq50_nums[Signal_freq50_values.index(i)])
print(index_overlap_signal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-986a6ac6900c> in <module>
#       1 index_overlap_signal = []
# ----> 2 for i in s_w_overlap:
#       3     index_overlap_signal.append(Signal_freq50_nums[Signal_freq50_values.index(i)])
#       4 print(index_overlap_signal)
#
# NameError: name 's_w_overlap' is not defined

# %%
plt.bar(range(len(index_overlap_signal)),  index_overlap_signal, color = 'b', tick_label = s_w_overlap)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f906d4f79363> in <module>
# ----> 1 plt.bar(range(len(index_overlap_signal)),  index_overlap_signal, color = 'b', tick_label = s_w_overlap)
#       2 plt.show()
#
# NameError: name 's_w_overlap' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
freq_N = np.arange(10)*100
freq_N += 100
signal_wire = [0.52, 0.575, 0.5667, 0.545, 0.57, 0.585, 0.5871, 0.5913, 0.5833, 0.591]
signal_firefox = [0.41, 0.43, 0.4733, 0.4975, 0.51, 0.5167, 0.5357, 0.535, 0.5289, 0.53]
signal_brave = [0.37, 0.435, 0.4333, 0.445, 0.446, 0.455, 0.4729, 0.465, 0.4822, 0.487]
signal_nextcloud = [0.46, 0.525, 0.5167, 0.535, 0.55, 0.5617, 0.5578, 0.5425, 0.5478, 0.541]
signal_owncloud = [0.39, 0.475, 0.4746, 0.51, 0.536, 0.5383, 0.5514, 0.55, 0.5544, 0.543]

#web_domain = 
yerr = np.linspace(0.05, 0.2, 10)

plt.xlabel('most frequent words in each app bug issues')
plt.ylabel('rate of sharing frequent words')
plt.xticks(rotation = 0)

plt.errorbar(freq_N, signal_wire, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-PS: signal & wire')
plt.errorbar(freq_N, signal_firefox, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-WB: signal & firefox')
plt.errorbar(freq_N, signal_brave, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-WB: signal & brave')
plt.errorbar(freq_N, signal_nextcloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-OS: signal & nextcloud')
plt.errorbar(freq_N, signal_owncloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-OS: signal & owncloud')

plt.legend(loc='lower right')
plt.savefig('privacy-sharing-hot-words.pdf')
plt.show()

# %% [markdown]
# ## wire

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
freq_N = np.arange(10)*100
freq_N += 100
wire_signal = [0.52, 0.575, 0.5667, 0.545, 0.57, 0.585, 0.5871, 0.5913, 0.5833, 0.591]
wire_firefox = [0.35, 0.455, 0.4567, 0.485, 0.514, 0.5383, 0.5371, 0.54, 0.5456, 0.54]
wire_brave = [0.32, 0.42, 0.4433, 0.4574, 0.476, 0.495, 0.4971, 0.5125, 0.5144, 0.511]
wire_nextcloud = [0.46, 0.51, 0.5133, 0.5175, 0.526, 0.54, 0.5329, 0.5438, 0.5367, 0.536]
wire_owncloud = [0.47, 0.495, 0.5033, 0.53, 0.528, 0.55, 0.55, 0.5512, 0.5422, 0.548]

#web_domain = 
yerr = np.linspace(0.05, 0.2, 10)

plt.xlabel('most frequent words in each app bug issues')
plt.ylabel('rate of sharing frequent words')
plt.xticks(rotation = 0)

plt.errorbar(freq_N, wire_signal, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-PS: wire & signal')
plt.errorbar(freq_N, wire_firefox, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-WB: wire & firefox')
plt.errorbar(freq_N, wire_brave, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-WB: wire & brave')
plt.errorbar(freq_N, wire_nextcloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-OS: wire & nextcloud')
plt.errorbar(freq_N, wire_owncloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='PS-OS: wire & owncloud')

plt.legend(loc='lower right')
plt.savefig('wire-sharing-hot-words.pdf')
plt.show()

# %% [markdown]
# ## Firefox

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
freq_N = np.arange(10)*100
freq_N += 100
firefox_brave = [0.42, 0.495, 0.5233, 0.5475, 0.558, 0.555, 0.5557, 0.56, 0.5611, 0.555]
firefox_signal = [0.39, 0.435, 0.46, 0.505, 0.522, 0.535, 0.5329, 0.5512, 0.54, 0.532]
firefox_wire = [0.39, 0.455, 0.4633, 0.4975, 0.524, 0.5417, 0.5543, 0.5575, 0.5378, 0.543]
firefox_nextcloud = [0.41, 0.455, 0.48, 0.515, 0.524, 0.52, 0.5171, 0.5238, 0.5222, 0.526]
firefox_owncloud = [0.36, 0.445, 0.4633, 0.4925, 0.522, 0.5383, 0.5329, 0.5488, 0.5322, 0.532]

#web_domain = 
yerr = np.linspace(0.05, 0.2, 10)

plt.xlabel('most frequent words in each app bug issues')
plt.ylabel('rate of sharing frequent words')
plt.xticks(rotation = 0)

plt.errorbar(freq_N, firefox_brave, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-WB: firefox & brave')
plt.errorbar(freq_N, firefox_signal, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-PS: firefox & signal')
plt.errorbar(freq_N, firefox_wire, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-PS: firefox & wire')
plt.errorbar(freq_N, firefox_nextcloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-OS: firefox & nextcloud')
plt.errorbar(freq_N, firefox_owncloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-OS: firefox & owncloud')

plt.legend(loc='lower right')
plt.savefig('firefox-sharing-hot-words.pdf')
plt.show()

# %% [markdown]
# ## Brave

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
freq_N = np.arange(10)*100
freq_N += 100
brave_firefox = [0.42, 0.495, 0.5233, 0.5475, 0.558, 0.555, 0.5557, 0.56, 0.5611, 0.555]
brave_signal = [0.37, 0.465, 0.4367, 0.4375, 0.438, 0.46, 0.48, 0.475, 0.4856, 0.485]
brave_wire = [0.34, 0.45, 0.4333, 0.4475, 0.464, 0.49, 0.49, 0.4962, 0.4944, 0.495]
brave_nextcloud = [0.41, 0.46, 0.4633, 0.455, 0.474, 0.4783, 0.4771, 0.4825, 0.4822, 0.471]
brave_owncloud = [0.4, 0.45, 0.42, 0.4525, 0.466, 0.475, 0.4786, 0.4925, 0.4956, 0.493]

#web_domain = 
yerr = np.linspace(0.05, 0.2, 10)

plt.xlabel('most frequent words in each app bug issues')
plt.ylabel('rate of sharing frequent words')
plt.xticks(rotation = 0)

plt.errorbar(freq_N, brave_firefox, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-WB: brave & firefox')
plt.errorbar(freq_N, brave_signal, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-PS: brave & signal')
plt.errorbar(freq_N, brave_wire, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-PS: brave & wire')
plt.errorbar(freq_N, brave_nextcloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-OS: brave & nextcloud')
plt.errorbar(freq_N, brave_owncloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='WB-OS: brave & owncloud')

plt.legend(loc='lower right')
plt.savefig('brave-sharing-hot-words.pdf')
plt.show()

# %% [markdown]
# ## Nextcloud

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
freq_N = np.arange(10)*100
freq_N += 100
nextcloud_owncloud = [0.63, 0.67, 0.6533, 0.6325, 0.668, 0.6467, 0.6386, 0.6275, 0.6278, 0.617]
nextcloud_signal = [0.46, 0.54, 0.51, 0.5325, 0.546, 0.5483, 0.5671, 0.5562, 0.5633, 0.552]
nextcloud_wire = [0.44, 0.51, 0.5233, 0.515, 0.52, 0.5483, 0.5429, 0.5425, 0.5478, 0.546]
nextcloud_firefox = [0.39, 0.43, 0.48, 0.525, 0.522, 0.53, 0.5371, 0.5425, 0.5367, 0.537]
nextcloud_brave = [0.41, 0.46, 0.4633, 0.455, 0.474, 0.4783, 0.4771, 0.4825, 0.4822, 0.471]

#web_domain = 
yerr = np.linspace(0.05, 0.2, 10)

plt.xlabel('most frequent words in each app bug issues')
plt.ylabel('rate of sharing frequent words')
plt.xticks(rotation = 0)

plt.errorbar(freq_N, nextcloud_owncloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-OS: nextcloud & owncloud')
plt.errorbar(freq_N, nextcloud_signal, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-PS: nextcloud & signal')
plt.errorbar(freq_N, nextcloud_wire, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-PS: nextcloud & wire')
plt.errorbar(freq_N, nextcloud_firefox, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-WB: nextcloud & firefox')
plt.errorbar(freq_N, nextcloud_brave, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-WB: nextcloud & brave')

plt.legend(loc='lower right')
plt.savefig('nextcloud-sharing-hot-words.pdf')
plt.show()

# %% [markdown]
# ## Owncloud

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
freq_N = np.arange(10)*100
freq_N += 100
owncloud_nextcloud = [0.63, 0.67, 0.6533, 0.6325, 0.668, 0.6467, 0.6386, 0.6275, 0.6278, 0.617]
owncloud_signal = [0.41, 0.49, 0.4833, 0.5225, 0.526, 0.535, 0.5486, 0.5475, 0.5522, 0.546]
owncloud_wire = [0.46, 0.505, 0.51, 0.5325, 0.538, 0.55, 0.5457, 0.5462, 0.5433, 0.55]
owncloud_firefox = [0.35, 0.45, 0.4533, 0.4925, 0.52, 0.53, 0.5371, 0.545, 0.5289, 0.533]
owncloud_brave = [0.4, 0.45, 0.42, 0.4525, 0.466, 0.475, 0.4786, 0.4925, 0.4956, 0.493]

#web_domain = 
yerr = np.linspace(0.05, 0.2, 10)

plt.xlabel('most frequent words in each app bug issues')
plt.ylabel('rate of sharing frequent words')
plt.xticks(rotation = 0)

plt.errorbar(freq_N, owncloud_nextcloud, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-OS: owncloud & nextcloud')
plt.errorbar(freq_N, owncloud_signal, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-PS: owncloud & signal')
plt.errorbar(freq_N, owncloud_wire, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-PS: owncloud & wire')
plt.errorbar(freq_N, owncloud_firefox, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-WB: owncloud & firefox')
plt.errorbar(freq_N, owncloud_brave, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='OS-WB: owncloud & brave')

plt.legend(loc='lower right')
plt.savefig('owncloud-sharing-hot-words.pdf')
plt.show()

# %%
privacy_domain = [0.52, 0.575, 0.5667, 0.545, 0.57, 0.585, 0.5871, 0.5913, 0.5833, 0.591]
privacy_office = [0.46, 0.525, 0.5167, 0.535, 0.55, 0.5617, 0.5578, 0.5425, 0.5478, 0.541]

pd = 0
pw = 0
for i in privacy_domain:
    pd+=i
for i in privacy_office:
    pw+=i
for i in range(10):
    print(privacy_domain[i]/privacy_office[i])
print(len(privacy_domain), len(privacy_office))
print(pd/pw)
# Out:
# 1.1304347826086956
# 1.0952380952380951
# 1.0967679504548091
# 1.0186915887850467
# 1.0363636363636362
# 1.0414812177318853
# 1.0525277877375403
# 1.0899539170506913
# 1.0648046732384084
# 1.0924214417744915
# 10 10
# 1.0706135831381733

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
freq_N = np.arange(10)*100
freq_N += 100
web_domain = [0.49, 0.505, 0.5267, 0.545, 0.548, 0.5533, 0.5557, 0.5538, 0.5644, 0.558]
web_privacy = [0.41, 0.43, 0.4733, 0.4975, 0.51, 0.5167, 0.5357, 0.535, 0.5289, 0.53]
web_office = [0.4, 0.455, 0.4933, 0.5425, 0.558, 0.5417, 0.5329, 0.5275, 0.5289, 0.522]

#web_domain = 
yerr = np.linspace(0.05, 0.2, 10)

plt.xlabel('most frequent words in each app bug issues')
plt.ylabel('rate of sharing frequent words')
plt.xticks(rotation = 0)

plt.errorbar(freq_N, web_domain, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='web-web: firefox & brave')
plt.errorbar(freq_N, web_privacy, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='web-privacy: firefox & signal')
plt.errorbar(freq_N, web_office, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='web-office: firefox & nextcloud')

plt.legend(loc='lower right')
plt.savefig('web-sharing-hot-words.pdf')
plt.show()

# %%
web_domain = [0.49, 0.505, 0.5267, 0.545, 0.548, 0.5533, 0.5557, 0.5538, 0.5644, 0.558]
web_office = [0.4, 0.455, 0.4933, 0.5425, 0.558, 0.5417, 0.5329, 0.5275, 0.5289, 0.522]

pd = 0
pw = 0
for i in web_domain:
    pd+=i
for i in web_office:
    pw+=i
for i in range(10):
    print(web_domain[i]/web_office[i])
print(len(web_domain), len(web_office))
print(pd/pw)
# Out:
# 1.2249999999999999
# 1.10989010989011
# 1.067707277518751
# 1.0046082949308757
# 0.9820788530465949
# 1.021414066826657
# 1.0427847626196283
# 1.0498578199052133
# 1.067120438646247
# 1.0689655172413794
# 10 10
# 1.0584303579128933

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
freq_N = np.arange(10)*100
freq_N += 100
office_domain = [0.61, 0.645, 0.6533, 0.635, 0.64, 0.6417, 0.6229, 0.6175, 0.6211, 0.615]
office_privacy = [0.46, 0.525, 0.5167, 0.535, 0.55, 0.5617, 0.5578, 0.5425, 0.5478, 0.541]
office_web = [0.4, 0.455, 0.4933, 0.5425, 0.558, 0.5417, 0.5329, 0.5275, 0.5289, 0.522]

#web_domain = 
yerr = np.linspace(0.05, 0.2, 10)

plt.xlabel('most frequent words in each app bug issues')
plt.ylabel('rate of sharing frequent words')
plt.xticks(rotation = 0)

plt.errorbar(freq_N, office_domain, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='office-office: nextcloud & owncloud')
plt.errorbar(freq_N, office_privacy, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='office-privacy: nextcloud & signal')
plt.errorbar(freq_N, office_web, marker = 'P', markersize = '8', linestyle = '--', linewidth =2, label='office-web: nextcloud & firefox')

plt.legend(loc='lower right')
plt.savefig('office-sharing-hot-words.pdf')
plt.show()

# %%
office_domain = [0.61, 0.645, 0.6533, 0.635, 0.64, 0.6417, 0.6229, 0.6175, 0.6211, 0.615]
office_privacy = [0.46, 0.525, 0.5167, 0.535, 0.55, 0.5617, 0.5578, 0.5425, 0.5478, 0.541]

pd = 0
pw = 0
for i in office_domain:
    pd+=i
for i in office_privacy:
    pw+=i
for i in range(10):
    print(office_domain[i]/office_privacy[i])
print(len(office_domain), len(office_privacy))
print(pd/pw)
# Out:
# 1.326086956521739
# 1.2285714285714286
# 1.264370040642539
# 1.1869158878504673
# 1.1636363636363636
# 1.1424247819120528
# 1.1167084976694157
# 1.1382488479262673
# 1.133807959109164
# 1.1367837338262476
# 10 10
# 1.180608899297424

# %% [markdown]
# ## RQ 1b

# %% [markdown]
# ### signal-brave

# %%
Signal_freq20_values= ['', 'signal', 'message', 'messages', 'sms', 'group', 'android', 'app', 'notification', 'contact', 'mms', 'send', 'call', 'add', 'feature', 'fix', 'crash', 'conversation', 'new', 'textsecure', 'text', 'request', 'button', 'sending', 'update', 'phone', 'video', 'crashes', 'emoji', 'time', 'number', 'sent', 'contacts', 'screen', 'error', 'support', 'use', 'chat', 'cannot', 'show', 'encrypted', 'media', 'list', 'image', 'notifications', 'calls', 'settings', 'theme', 'option', 'back', 'received'] 
Signal_freq20_nums= [582, 334, 315, 274, 197, 183, 140, 138, 134, 131, 120, 119, 110, 110, 106, 103, 101, 94, 93, 90, 87, 84, 79, 73, 73, 72, 71, 71, 70, 67, 67, 66, 65, 64, 62, 60, 60, 58, 57, 55, 55, 55, 53, 52, 49, 49, 47, 47, 46, 46, 46]
Wire_freq20_values= ['', 'brave', 'x', 'release', 'android', 'chromium', 'add', 'test', 'desktop', 'rewards', 'ads', 'run', 'browser', 'manual', 'wallet', 'tab', 'page', 'upgrade', 'settings', 'update', 'sync', 'new', 'windows', 'remove', 'notes', 'linux', 'ad', 'shields', 'fix', 'feature', 'panel', 'window', 'crash', 'build', 'macos', 'chrome', 'site', 'error', 'widget', 'default', 'follow', 'bar', 'text', 'icon', 'ui', 'private', 'support', 'tor', 'use', 'channel', 'implement'] 
Wire_freq20_nums = [1932, 538, 358, 313, 231, 228, 198, 173, 167, 165, 163, 162, 141, 141, 125, 125, 120, 119, 112, 111, 105, 99, 84, 84, 75, 75, 72, 71, 71, 68, 67, 67, 66, 65, 65, 62, 61, 60, 60, 59, 59, 57, 56, 54, 54, 54, 53, 53, 53, 52, 52]
s_w_overlap = ['android', 'add', 'feature', 'fix', 'support', 'error', 'use', 'text', 'crash', 'settings', 'update', 'new']

print(len(Signal_freq20_values), len(Signal_freq20_nums), len(Wire_freq20_values), len(Wire_freq20_nums))
# Out:
# 51 51 51 51

# %%
index_overlap_signal = []
for i in s_w_overlap:
    index_overlap_signal.append(Signal_freq20_nums[Signal_freq20_values.index(i)])
print(index_overlap_signal)

index_overlap_wire = []
for i in s_w_overlap:
    index_overlap_wire.append(Wire_freq20_nums[Wire_freq20_values.index(i)])
print(index_overlap_wire)
# Out:
# [140, 110, 106, 103, 60, 62, 60, 87, 101, 47, 73, 93]
# [231, 198, 68, 71, 53, 60, 53, 56, 66, 112, 111, 99]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = s_w_overlap
A_ = index_overlap_signal
B_ = index_overlap_wire
print(len(A_), len(s_w_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'PS: signal')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'WB: brave')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in signal and wire')
ax.set_xticks(x, s_w_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper center')
plt.savefig('sharing_words_and_occurred_times_signal_brave.pdf')
plt.show()
# Out:
# 12 12

# %% [markdown]
# ### signal-Owncloud

# %%
Signal_freq20_values= ['', 'signal', 'message', 'messages', 'sms', 'group', 'android', 'app', 'notification', 'contact', 'mms', 'send', 'call', 'add', 'feature', 'fix', 'crash', 'conversation', 'new', 'textsecure', 'text', 'request', 'button', 'sending', 'update', 'phone', 'video', 'crashes', 'emoji', 'time', 'number', 'sent', 'contacts', 'screen', 'error', 'support', 'use', 'chat', 'cannot', 'show', 'encrypted', 'media', 'list', 'image', 'notifications', 'calls', 'settings', 'theme', 'option', 'back', 'received'] 
Signal_freq20_nums= [582, 334, 315, 274, 197, 183, 140, 138, 134, 131, 120, 119, 110, 110, 106, 103, 101, 94, 93, 90, 87, 84, 79, 73, 73, 72, 71, 71, 70, 67, 67, 66, 65, 64, 62, 60, 60, 58, 57, 55, 55, 55, 53, 52, 49, 49, 47, 47, 46, 46, 46] 
Firefox_freq20_values= ['', 'app', 'bump', 'upload', 'android', 'crash', 'files', 'fix', 'file', 'nextcloud', 'folder', 'auto', 'stable', 'add', 'error', 'rc', 'use', 'server', 'new', 'crashes', 'account', 'show', 'user', 'login', 'view', 'share', 'open', 'gradle', 'version', 'npe', 'work', 'remove', 'video', 'bug', 'folders', 'notification', 'search', 'update', 'autoupload', 'sync', 'screen', 'preview', 'text', 'activity', 'uploads', 'storage', 'sharing', 'uploading', 'client', 'photos', 'dev'] 
Firefox_freq20_nums = [2284, 305, 274, 258, 252, 212, 189, 180, 180, 158, 150, 139, 123, 115, 106, 96, 95, 86, 78, 74, 67, 65, 60, 55, 53, 53, 53, 52, 51, 50, 50, 50, 47, 46, 42, 41, 41, 41, 40, 39, 39, 39, 39, 39, 38, 38, 38, 37, 37, 36, 36]
s_f_overlap = ['android', 'screen', 'text', 'new', 'crashes', 'add', 'use', 'error', 'update', 'crash', 'notification', 'app', 'fix', 'video', 'show']

# %%
print(len(Signal_freq20_values), len(Signal_freq20_nums), len(Firefox_freq20_values), len(Firefox_freq20_nums))
# Out:
# 51 51 51 51

# %%
index_overlap_signal = []
for i in s_f_overlap:
    index_overlap_signal.append(Signal_freq20_nums[Signal_freq20_values.index(i)])
print(index_overlap_signal)

index_overlap_firefox = []
for i in s_f_overlap:
    index_overlap_firefox.append(Firefox_freq20_nums[Firefox_freq20_values.index(i)])
print(index_overlap_firefox)
# Out:
# [140, 64, 87, 93, 71, 110, 60, 62, 73, 101, 134, 138, 103, 71, 55]
# [252, 39, 39, 78, 74, 115, 95, 106, 41, 212, 41, 305, 180, 47, 65]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = s_f_overlap
A_ = index_overlap_signal
B_ = index_overlap_firefox
print(len(A_), len(s_f_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'PS: signal')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'OS: nextcloud')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in signal and firefox')
ax.set_xticks(x, s_f_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper center')
plt.savefig('sharing_words_and_occurred_times_signal_nextcloud.pdf')
plt.show()
# Out:
# 15 15

# %% [markdown]
# ### wire-firefox

# %%
Signal_freq20_values= ['', 'fix', 'feature', 'add', 'conversation', 'calling', 'message', 'part', 'avs', 'call', 'update', 'bump', 'wire', 'new', 'messages', 'user', 'remove', 'app', 'android', 'video', 'se', 'notifications', 'version', 'feat', 'screen', 'notification', 'request', 'chore', 'calls', 'refactor', 'group', 'use', 'list', 'team', 'fixes', 'button', 'show', 'tests', 'account', 'search', 'code', 'audio', 'file', 'change', 'ui', 'legal', 'hold', 'conversations', 'link', 'error', 'kotlin'] 
Signal_freq20_nums= [1257, 512, 214, 178, 151, 149, 133, 131, 130, 123, 122, 122, 120, 119, 116, 115, 109, 106, 100, 99, 98, 93, 92, 85, 84, 79, 79, 72, 66, 66, 60, 60, 60, 60, 58, 58, 58, 57, 55, 54, 54, 53, 52, 50, 50, 50, 50, 48, 47, 46, 46] 
Nextcloud_freq20_values= ['', 'bug', 'fnx', '⁃', 'android', 'add', 'tab', 'tabs', 'update', 'search', 'ui', 'fenix', 'components', 'test', 'version', 'menu', 'issue', 'screen', 'private', 'button', 'bar', 'app', 'page', 'mode', 'strings', 'open', 'new', 'fix', 'crash', 'closes', 'text', 'tray', 'history', 'ln', 'firefox', 'settings', 'remove', 'color', 'use', 'telemetry', 'collection', 'top', 'toolbar', 'import', 'url', 'custom', 'home', 'browser', 'site', 'intermittent', 'bookmarks'] 

Nextcloud_freq20_nums = [1407, 984, 352, 350, 259, 247, 246, 230, 210, 173, 134, 126, 125, 122, 118, 118, 116, 115, 112, 106, 105, 102, 99, 96, 96, 96, 95, 93, 91, 88, 88, 87, 83, 80, 78, 76, 73, 73, 72, 70, 68, 68, 67, 67, 67, 66, 65, 65, 65, 64, 61]

s_n_overlap = ['fix', 'use', 'button', 'add', 'screen', 'android', 'ui', 'remove', 'app', 'new', 'update', 'version', 'search']

# %%
print(len(Signal_freq20_values), len(Signal_freq20_nums), len(Nextcloud_freq20_values), len(Nextcloud_freq20_nums))
# Out:
# 51 51 51 51

# %%
index_overlap_signal = []
for i in s_n_overlap:
    index_overlap_signal.append(Signal_freq20_nums[Signal_freq20_values.index(i)])
print(index_overlap_signal)

index_overlap_nextcloud = []
for i in s_n_overlap:
    index_overlap_nextcloud.append(Nextcloud_freq20_nums[Nextcloud_freq20_values.index(i)])
print(index_overlap_nextcloud)
# Out:
# [512, 60, 58, 178, 84, 100, 50, 109, 106, 119, 122, 92, 54]
# [93, 72, 106, 247, 115, 259, 134, 73, 102, 95, 210, 118, 173]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = s_n_overlap
A_ = index_overlap_signal
B_ = index_overlap_nextcloud
print(len(A_), len(s_n_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'PS: wire')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'WB: firefox')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in signal and nextcloud')
ax.set_xticks(x, s_n_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper right')
plt.savefig('sharing_words_and_occurred_times_wire_firefox.pdf')
plt.show()
# Out:
# 13 13

# %% [markdown]
# ### wire-brave

# %%
Firefox_freq20_values= ['', 'fix', 'feature', 'add', 'conversation', 'calling', 'message', 'part', 'avs', 'call', 'update', 'bump', 'wire', 'new', 'messages', 'user', 'remove', 'app', 'android', 'video', 'se', 'notifications', 'version', 'feat', 'screen', 'notification', 'request', 'chore', 'calls', 'refactor', 'group', 'use', 'list', 'team', 'fixes', 'button', 'show', 'tests', 'account', 'search', 'code', 'audio', 'file', 'change', 'ui', 'legal', 'hold', 'conversations', 'link', 'error', 'kotlin']
Firefox_freq20_nums = [1257, 512, 214, 178, 151, 149, 133, 131, 130, 123, 122, 122, 120, 119, 116, 115, 109, 106, 100, 99, 98, 93, 92, 85, 84, 79, 79, 72, 66, 66, 60, 60, 60, 60, 58, 58, 58, 57, 55, 54, 54, 53, 52, 50, 50, 50, 50, 48, 47, 46, 46] 
Brave_freq20_values = ['', 'brave', 'x', 'release', 'android', 'chromium', 'add', 'test', 'desktop', 'rewards', 'ads', 'run', 'browser', 'manual', 'wallet', 'tab', 'page', 'upgrade', 'settings', 'update', 'sync', 'new', 'windows', 'remove', 'notes', 'linux', 'ad', 'shields', 'fix', 'feature', 'panel', 'window', 'crash', 'build', 'macos', 'chrome', 'site', 'error', 'widget', 'default', 'follow', 'bar', 'text', 'icon', 'ui', 'private', 'support', 'tor', 'use', 'channel', 'implement'] 
Brave_freq20_nums = [1932, 538, 358, 313, 231, 228, 198, 173, 167, 165, 163, 162, 141, 141, 125, 125, 120, 119, 112, 111, 105, 99, 84, 84, 75, 75, 72, 71, 71, 68, 67, 67, 66, 65, 65, 62, 61, 60, 60, 59, 59, 57, 56, 54, 54, 54, 53, 53, 53, 52, 52]
f_b_overlap = ['feature', 'remove', 'android', 'add', 'update', 'fix', 'ui', 'new', 'error', 'use']

# %%
print(len(Firefox_freq20_values), len(Firefox_freq20_nums), len(Brave_freq20_values), len(Brave_freq20_nums))
# Out:
# 51 51 51 51

# %%
index_overlap_firefox = []
for i in f_b_overlap:
    index_overlap_firefox.append(Firefox_freq20_nums[Firefox_freq20_values.index(i)])
print(index_overlap_firefox)

index_overlap_brave = []
for i in f_b_overlap:
    index_overlap_brave.append(Brave_freq20_nums[Brave_freq20_values.index(i)])
print(index_overlap_brave)
# Out:
# [214, 109, 100, 178, 122, 512, 50, 119, 46, 60]
# [68, 84, 231, 198, 111, 71, 54, 99, 60, 53]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = f_b_overlap
A_ = index_overlap_firefox
B_ = index_overlap_brave
print(len(A_), len(f_b_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'PS: wire')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'WB: brave')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in firefox and brave')
ax.set_xticks(x, f_b_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper center')
plt.savefig('sharing_words_and_occurred_times_wire_brave.pdf')
plt.show()
# Out:
# 10 10

# %% [markdown]
# ### wire-nextcloud

# %%
Firefox_freq20_values= ['', 'fix', 'feature', 'add', 'conversation', 'calling', 'message', 'part', 'avs', 'call', 'update', 'bump', 'wire', 'new', 'messages', 'user', 'remove', 'app', 'android', 'video', 'se', 'notifications', 'version', 'feat', 'screen', 'notification', 'request', 'chore', 'calls', 'refactor', 'group', 'use', 'list', 'team', 'fixes', 'button', 'show', 'tests', 'account', 'search', 'code', 'audio', 'file', 'change', 'ui', 'legal', 'hold', 'conversations', 'link', 'error', 'kotlin']
Firefox_freq20_nums = [1257, 512, 214, 178, 151, 149, 133, 131, 130, 123, 122, 122, 120, 119, 116, 115, 109, 106, 100, 99, 98, 93, 92, 85, 84, 79, 79, 72, 66, 66, 60, 60, 60, 60, 58, 58, 58, 57, 55, 54, 54, 53, 52, 50, 50, 50, 50, 48, 47, 46, 46] 
Nextcloud_freq20_values= ['', 'app', 'bump', 'upload', 'android', 'crash', 'files', 'fix', 'file', 'nextcloud', 'folder', 'auto', 'stable', 'add', 'error', 'rc', 'use', 'server', 'new', 'crashes', 'account', 'show', 'user', 'login', 'view', 'share', 'open', 'gradle', 'version', 'npe', 'work', 'remove', 'video', 'bug', 'folders', 'notification', 'search', 'update', 'autoupload', 'sync', 'screen', 'preview', 'text', 'activity', 'uploads', 'storage', 'sharing', 'uploading', 'client', 'photos', 'dev'] 
Nextcloud_freq20_nums = [2284, 305, 274, 258, 252, 212, 189, 180, 180, 158, 150, 139, 123, 115, 106, 96, 95, 86, 78, 74, 67, 65, 60, 55, 53, 53, 53, 52, 51, 50, 50, 50, 47, 46, 42, 41, 41, 41, 40, 39, 39, 39, 39, 39, 38, 38, 38, 37, 37, 36, 36]

f_n_overlap = ['file', 'account', 'version', 'video', 'remove', 'use', 'update', 'error', 'show', 'android', 'new', 'fix', 'search', 'user', 'add', 'bump', 'app', 'notification', 'screen']

# %%
print(len(Firefox_freq20_values), len(Firefox_freq20_nums), len(Nextcloud_freq20_values), len(Nextcloud_freq20_nums))
# Out:
# 51 51 51 51

# %%
index_overlap_firefox = []
for i in f_n_overlap:
    index_overlap_firefox.append(Firefox_freq20_nums[Firefox_freq20_values.index(i)])
print(index_overlap_firefox)

index_overlap_nextcloud = []
for i in f_n_overlap:
    index_overlap_nextcloud.append(Nextcloud_freq20_nums[Nextcloud_freq20_values.index(i)])
print(index_overlap_nextcloud)
# Out:
# [52, 55, 92, 99, 109, 60, 122, 46, 58, 100, 119, 512, 54, 115, 178, 122, 106, 79, 84]
# [180, 67, 51, 47, 50, 95, 41, 106, 65, 252, 78, 180, 41, 60, 115, 274, 305, 41, 39]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = f_n_overlap
A_ = index_overlap_firefox
B_ = index_overlap_nextcloud
print(len(A_), len(f_n_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'PS: wire')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'OS: nextcloud')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in firefox and nextcloud')
ax.set_xticks(x, f_n_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper center')
plt.savefig('sharing_words_and_occurred_times_wire_nextcloud.pdf')
plt.show()
# Out:
# 19 19

# %% [markdown]
# ### nextcloud-owncloud

# %%
Nextcloud_freq20_values= ['', 'fix', 'feature', 'add', 'conversation', 'calling', 'message', 'part', 'avs', 'call', 'update', 'bump', 'wire', 'new', 'messages', 'user', 'remove', 'app', 'android', 'video', 'se', 'notifications', 'version', 'feat', 'screen', 'notification', 'request', 'chore', 'calls', 'refactor', 'group', 'use', 'list', 'team', 'fixes', 'button', 'show', 'tests', 'account', 'search', 'code', 'audio', 'file', 'change', 'ui', 'legal', 'hold', 'conversations', 'link', 'error', 'kotlin'] 
Nextcloud_freq20_nums = [1257, 512, 214, 178, 151, 149, 133, 131, 130, 123, 122, 122, 120, 119, 116, 115, 109, 106, 100, 99, 98, 93, 92, 85, 84, 79, 79, 72, 66, 66, 60, 60, 60, 60, 58, 58, 58, 57, 55, 54, 54, 53, 52, 50, 50, 50, 50, 48, 47, 46, 46]

Owncloud_freq20_values = ['', 'android', 'new', 'upload', 'files', 'app', 'file', 'folder', 'fix', 'owncloud', 'feature', 'request', 'bug', 'release', 'update', 'share', 'uploads', 'add', 'arch', 'bump', 'server', 'beta', 'view', 'version', 'error', 'account', 'crash', 'sync', 'instant', 'user', 'support', 'show', 'login', 'download', 'use', 'remove', 'link', 'settings', 'list', 'oc', 'client', 'folders', 'name', 'failed', 'sharing', 'menu', 'build', 'camera', 'public', 'create', 'log']
Owncloud_freq20_nums = [1444, 273, 236, 235, 199, 194, 180, 176, 158, 151, 151, 143, 139, 136, 118, 117, 97, 97, 96, 95, 95, 92, 91, 90, 86, 79, 72, 72, 71, 68, 65, 64, 63, 62, 62, 62, 57, 56, 51, 50, 50, 50, 47, 44, 44, 44, 42, 42, 41, 39, 38]
n_o_overlap = ['link', 'remove', 'android', 'fix', 'list', 'new', 'show', 'app', 'version', 'bump', 'user', 'feature', 'use', 'file', 'request', 'update', 'account', 'error', 'add']

# %%
print(len(Nextcloud_freq20_values), len(Nextcloud_freq20_nums), len(Owncloud_freq20_values), len(Owncloud_freq20_nums))
# Out:
# 51 51 51 51

# %%
index_overlap_nextcloud = []
for i in n_o_overlap:
    index_overlap_nextcloud.append(Nextcloud_freq20_nums[Nextcloud_freq20_values.index(i)])
print(index_overlap_nextcloud)

index_overlap_owncloud = []
for i in n_o_overlap:
    index_overlap_owncloud.append(Owncloud_freq20_nums[Owncloud_freq20_values.index(i)])
print(index_overlap_owncloud)
# Out:
# [47, 109, 100, 512, 60, 119, 58, 106, 92, 122, 115, 214, 60, 52, 79, 122, 55, 46, 178]
# [57, 62, 273, 158, 51, 236, 64, 194, 90, 95, 68, 151, 62, 180, 143, 118, 79, 86, 97]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = n_o_overlap
A_ = index_overlap_nextcloud
B_ = index_overlap_owncloud
print(len(A_), len(n_o_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'PS: wire')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'OS: owncloud')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in nextcloud and owncloud')
ax.set_xticks(x, n_o_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper right')
plt.savefig('sharing_words_and_occurred_times_wire_owncloud.pdf')
plt.show()
# Out:
# 19 19

# %% [markdown]
# # firefox-owncloud

# %%
Nextcloud_freq20_values= ['', 'bug', 'fnx', '⁃', 'android', 'add', 'tab', 'tabs', 'update', 'search', 'ui', 'fenix', 'components', 'test', 'version', 'menu', 'issue', 'screen', 'private', 'button', 'bar', 'app', 'page', 'mode', 'strings', 'open', 'new', 'fix', 'crash', 'closes', 'text', 'tray', 'history', 'ln', 'firefox', 'settings', 'remove', 'color', 'use', 'telemetry', 'collection', 'top', 'toolbar', 'import', 'url', 'custom', 'home', 'browser', 'site', 'intermittent', 'bookmarks']
Nextcloud_freq20_nums = [1407, 984, 352, 350, 259, 247, 246, 230, 210, 173, 134, 126, 125, 122, 118, 118, 116, 115, 112, 106, 105, 102, 99, 96, 96, 96, 95, 93, 91, 88, 88, 87, 83, 80, 78, 76, 73, 73, 72, 70, 68, 68, 67, 67, 67, 66, 65, 65, 65, 64, 61] 

Owncloud_freq20_values = ['', 'android', 'new', 'upload', 'files', 'app', 'file', 'folder', 'fix', 'owncloud', 'feature', 'request', 'bug', 'release', 'update', 'share', 'uploads', 'add', 'arch', 'bump', 'server', 'beta', 'view', 'version', 'error', 'account', 'crash', 'sync', 'instant', 'user', 'support', 'show', 'login', 'download', 'use', 'remove', 'link', 'settings', 'list', 'oc', 'client', 'folders', 'name', 'failed', 'sharing', 'menu', 'build', 'camera', 'public', 'create', 'log'] 

Owncloud_freq20_nums = [1444, 273, 236, 235, 199, 194, 180, 176, 158, 151, 151, 143, 139, 136, 118, 117, 97, 97, 96, 95, 95, 92, 91, 90, 86, 79, 72, 72, 71, 68, 65, 64, 63, 62, 62, 62, 57, 56, 51, 50, 50, 50, 47, 44, 44, 44, 42, 42, 41, 39, 38]
n_o_overlap = ['app', 'settings', 'bug', 'menu', 'remove', 'new', 'update', 'crash', 'android', 'version', 'fix', 'use', 'add']

# %%
index_overlap_nextcloud = []
for i in n_o_overlap:
    index_overlap_nextcloud.append(Nextcloud_freq20_nums[Nextcloud_freq20_values.index(i)])
print(index_overlap_nextcloud)

index_overlap_owncloud = []
for i in n_o_overlap:
    index_overlap_owncloud.append(Owncloud_freq20_nums[Owncloud_freq20_values.index(i)])
print(index_overlap_owncloud)
# Out:
# [102, 76, 984, 118, 73, 95, 210, 91, 259, 118, 93, 72, 247]
# [194, 56, 139, 44, 62, 236, 118, 72, 273, 90, 158, 62, 97]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = n_o_overlap
A_ = index_overlap_nextcloud
B_ = index_overlap_owncloud
print(len(A_), len(n_o_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'WB: firefox')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'OS: owncloud')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in nextcloud and owncloud')
ax.set_xticks(x, n_o_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper right')
plt.savefig('sharing_words_and_occurred_times_firefox_owncloud.pdf')
plt.show()
# Out:
# 13 13

# %% [markdown]
# # Brave-Nextcloud

# %%
Nextcloud_freq20_values= ['', 'brave', 'x', 'release', 'android', 'chromium', 'add', 'test', 'desktop', 'rewards', 'ads', 'run', 'browser', 'manual', 'wallet', 'tab', 'page', 'upgrade', 'settings', 'update', 'sync', 'new', 'windows', 'remove', 'notes', 'linux', 'ad', 'shields', 'fix', 'feature', 'panel', 'window', 'crash', 'build', 'macos', 'chrome', 'site', 'error', 'widget', 'default', 'follow', 'bar', 'text', 'icon', 'ui', 'private', 'support', 'tor', 'use', 'channel', 'implement'] 
Nextcloud_freq20_nums = [1932, 538, 358, 313, 231, 228, 198, 173, 167, 165, 163, 162, 141, 141, 125, 125, 120, 119, 112, 111, 105, 99, 84, 84, 75, 75, 72, 71, 71, 68, 67, 67, 66, 65, 65, 62, 61, 60, 60, 59, 59, 57, 56, 54, 54, 54, 53, 53, 53, 52, 52]

Owncloud_freq20_values = ['', 'app', 'bump', 'upload', 'android', 'crash', 'files', 'fix', 'file', 'nextcloud', 'folder', 'auto', 'stable', 'add', 'error', 'rc', 'use', 'server', 'new', 'crashes', 'account', 'show', 'user', 'login', 'view', 'share', 'open', 'gradle', 'version', 'npe', 'work', 'remove', 'video', 'bug', 'folders', 'notification', 'search', 'update', 'autoupload', 'sync', 'screen', 'preview', 'text', 'activity', 'uploads', 'storage', 'sharing', 'uploading', 'client', 'photos', 'dev'] 
Owncloud_freq20_nums = [2284, 305, 274, 258, 252, 212, 189, 180, 180, 158, 150, 139, 123, 115, 106, 96, 95, 86, 78, 74, 67, 65, 60, 55, 53, 53, 53, 52, 51, 50, 50, 50, 47, 46, 42, 41, 41, 41, 40, 39, 39, 39, 39, 39, 38, 38, 38, 37, 37, 36, 36]
n_o_overlap = ['fix', 'new', 'text', 'add', 'android', 'error', 'crash', 'update', 'sync', 'remove', 'use']

# %%
index_overlap_nextcloud = []
for i in n_o_overlap:
    index_overlap_nextcloud.append(Nextcloud_freq20_nums[Nextcloud_freq20_values.index(i)])
print(index_overlap_nextcloud)

index_overlap_owncloud = []
for i in n_o_overlap:
    index_overlap_owncloud.append(Owncloud_freq20_nums[Owncloud_freq20_values.index(i)])
print(index_overlap_owncloud)
# Out:
# [71, 99, 56, 198, 231, 60, 66, 111, 105, 84, 53]
# [180, 78, 39, 115, 252, 106, 212, 41, 39, 50, 95]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = n_o_overlap
A_ = index_overlap_nextcloud
B_ = index_overlap_owncloud
print(len(A_), len(n_o_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'WB: brave')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'OS: nextcloud')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in nextcloud and owncloud')
ax.set_xticks(x, n_o_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper right')
plt.savefig('sharing_words_and_occurred_times_brave_nextcloud.pdf')
plt.show()
# Out:
# 11 11

# %% [markdown]
# # brave-owncloud

# %%
Nextcloud_freq20_values= ['', 'brave', 'x', 'release', 'android', 'chromium', 'add', 'test', 'desktop', 'rewards', 'ads', 'run', 'browser', 'manual', 'wallet', 'tab', 'page', 'upgrade', 'settings', 'update', 'sync', 'new', 'windows', 'remove', 'notes', 'linux', 'ad', 'shields', 'fix', 'feature', 'panel', 'window', 'crash', 'build', 'macos', 'chrome', 'site', 'error', 'widget', 'default', 'follow', 'bar', 'text', 'icon', 'ui', 'private', 'support', 'tor', 'use', 'channel', 'implement'] 
Nextcloud_freq20_nums = [1932, 538, 358, 313, 231, 228, 198, 173, 167, 165, 163, 162, 141, 141, 125, 125, 120, 119, 112, 111, 105, 99, 84, 84, 75, 75, 72, 71, 71, 68, 67, 67, 66, 65, 65, 62, 61, 60, 60, 59, 59, 57, 56, 54, 54, 54, 53, 53, 53, 52, 52] 

Owncloud_freq20_values = ['', 'android', 'new', 'upload', 'files', 'app', 'file', 'folder', 'fix', 'owncloud', 'feature', 'request', 'bug', 'release', 'update', 'share', 'uploads', 'add', 'arch', 'bump', 'server', 'beta', 'view', 'version', 'error', 'account', 'crash', 'sync', 'instant', 'user', 'support', 'show', 'login', 'download', 'use', 'remove', 'link', 'settings', 'list', 'oc', 'client', 'folders', 'name', 'failed', 'sharing', 'menu', 'build', 'camera', 'public', 'create', 'log'] 

Owncloud_freq20_nums = [1444, 273, 236, 235, 199, 194, 180, 176, 158, 151, 151, 143, 139, 136, 118, 117, 97, 97, 96, 95, 95, 92, 91, 90, 86, 79, 72, 72, 71, 68, 65, 64, 63, 62, 62, 62, 57, 56, 51, 50, 50, 50, 47, 44, 44, 44, 42, 42, 41, 39, 38]
n_o_overlap = ['settings', 'new', 'error', 'fix', 'support', 'remove', 'build', 'update', 'use', 'crash', 'android', 'add', 'sync', 'feature', 'release']

# %%
index_overlap_nextcloud = []
for i in n_o_overlap:
    index_overlap_nextcloud.append(Nextcloud_freq20_nums[Nextcloud_freq20_values.index(i)])
print(index_overlap_nextcloud)

index_overlap_owncloud = []
for i in n_o_overlap:
    index_overlap_owncloud.append(Owncloud_freq20_nums[Owncloud_freq20_values.index(i)])
print(index_overlap_owncloud)
# Out:
# [112, 99, 60, 71, 53, 84, 65, 111, 53, 66, 231, 198, 105, 68, 313]
# [56, 236, 86, 158, 65, 62, 42, 118, 62, 72, 273, 97, 72, 151, 136]

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = n_o_overlap
A_ = index_overlap_nextcloud
B_ = index_overlap_owncloud
print(len(A_), len(n_o_overlap))


x = np.arange(len(labels)) # the label locations
width = 0.35 # width of the bars

# patterns = ('/','//','-', '+', 'x', '\\', '\\\\', '*', 'o', 'O', '.')

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, A_, width, color = 'white', edgecolor = 'black', hatch= '*', label = 'WB: brave')
rects2 = ax.bar(x + width/2, B_, width, color = 'white', edgecolor = 'black', hatch= '--', label = 'OS: owncloud')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Occurred times')
ax.set_title('sharing words and occurred times in nextcloud and owncloud')
ax.set_xticks(x, n_o_overlap)
ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

plt.xticks(rotation=30)

fig.tight_layout()

plt.legend(loc='upper right')
plt.savefig('sharing_words_and_occurred_times_brave_owncloud.pdf')
plt.show()
# Out:
# 15 15
